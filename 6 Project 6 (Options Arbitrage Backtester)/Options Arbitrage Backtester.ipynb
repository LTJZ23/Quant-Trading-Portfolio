# %%
import pandas as pd
import numpy as np
import yfinance as yf
from scipy.stats import norm
from backtesting import Backtest, Strategy,set_bokeh_output
from datetime import datetime
set_bokeh_output(notebook=False)

# Load Options Data
df_Options = pd.read_parquet(r"...\Merged_2023_SPY_Options.parquet")
df_Options ['QUOTE_DATE'] = pd.to_datetime(df_Options['QUOTE_DATE'])
df_Options ['EXPIRE_DATE'] = pd.to_datetime(df_Options['EXPIRE_DATE'])
df_Options ['T'] = (df_Options ['EXPIRE_DATE'] - df_Options ['QUOTE_DATE']).dt.days/365
df_Options = df_Options[df_Options ['T'] > 0]

# Convert numeric columns explicitly
for col in ['C_BID', 'C_ASK', 'P_BID', 'P_ASK', 'STRIKE']:
    df_Options[col] = pd.to_numeric(df_Options[col], errors='coerce')

Nth_Closest_Expiry =12
def Get_Nth_Closest_Expiry (group, n = Nth_Closest_Expiry):
    Option_Expiry = group['EXPIRE_DATE'].unique()
    Option_Expiry_Sorted = sorted(Option_Expiry)

    if len(Option_Expiry_Sorted) >=n:
        Nth_Closest_Expiry = Option_Expiry_Sorted[n-1]
        return group[group['EXPIRE_DATE']==Nth_Closest_Expiry]
    return group[group['EXPIRE_DATE']==Option_Expiry_Sorted[-1]]

#filter to 2nd closest expiry
df_Option_Filtered = df_Options.groupby('QUOTE_DATE').apply(Get_Nth_Closest_Expiry).reset_index(drop=True)

def Historical_Volatility (Price, Window = 30):
    Log_Returns = np.log(Price/(Price.shift(1)).dropna())
    Rolling_Log_Returns = Log_Returns.rolling(window=Window).std() * np.sqrt(252)
    return Rolling_Log_Returns

# Load SPY Data
df_SPY = yf.download("SPY", start= "2022-10-15", end="2024-01-01" , progress=False)[['Close']]
df_SPY.columns = ['SPY_CLOSE']
df_SPY=df_SPY.reset_index()
df_SPY['HISTORICAL_VOLATILITY'] = Historical_Volatility(df_SPY['SPY_CLOSE'])


# Merge Data
df_Merged = pd.merge(df_Option_Filtered,df_SPY[['Date','SPY_CLOSE','HISTORICAL_VOLATILITY']],left_on='QUOTE_DATE',right_on='Date', how='left')
df_Merged = df_Merged[['QUOTE_DATE', 'EXPIRE_DATE', 'SPY_CLOSE','HISTORICAL_VOLATILITY','T','C_BID', 'C_ASK','P_BID', 'P_ASK','STRIKE','C_LAST','P_LAST']]
df_Merged['STRIKE_DIFF'] = abs(df_Merged['SPY_CLOSE'] - df_Merged["STRIKE"])



df_Merged_Strike = df_Merged.iloc[df_Merged.groupby('QUOTE_DATE')['STRIKE_DIFF'].idxmin()].drop(columns=['STRIKE_DIFF']).reset_index(drop=True)

Risk_Free_Rate = 0.05
def Black_Scholes(S, K, T, r, Sigma, Option_Type = 'Call'):
    d1 = (np.log(S / K) + (r + 0.5 * Sigma**2) * T) / (Sigma * np.sqrt(T))
    d2 = d1 - Sigma * np.sqrt(T)
    if Option_Type == 'Call':
        BS_Price = S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    else:  # put
        BS_Price = K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    return BS_Price


df_Merged_Strike['BS_CALL_HV'] = df_Merged_Strike.apply(
    lambda row: Black_Scholes(row['SPY_CLOSE'], row['STRIKE'], row['T'], Risk_Free_Rate, row['HISTORICAL_VOLATILITY'], 'Call'),
    axis=1
)

df_Merged_Strike['BS_PUT_HV'] = df_Merged_Strike.apply(
    lambda row: Black_Scholes(row['SPY_CLOSE'], row['STRIKE'], row['T'], Risk_Free_Rate, row['HISTORICAL_VOLATILITY'], 'put'),
    axis=1
)

df_Merged_Strike['CALL_DIFF'] =  (((df_Merged_Strike['C_BID'] + df_Merged_Strike['C_ASK'])/2)- df_Merged_Strike['BS_CALL_HV'])/((df_Merged_Strike['C_BID'] + df_Merged_Strike['C_ASK'])/2)
df_Merged_Strike['PUT_DIFF'] =  (((df_Merged_Strike['P_BID'] + df_Merged_Strike['P_ASK'])/2)- df_Merged_Strike['BS_PUT_HV'])/((df_Merged_Strike['P_BID'] + df_Merged_Strike['P_ASK'])/2)
df_Merged_Strike.to_csv(r"...\Merged_Strike.csv")

# Notes, 2nd closest Option prices differ largely from BS calculated Options, hence why we used n = 12

# Prepare backtesting DataFrames (keeping your original static price setup)
df_BT_Call = df_Merged_Strike.copy()
df_BT_Call['DATE'] = pd.to_datetime(df_BT_Call['QUOTE_DATE'])
df_BT_Call = df_BT_Call.set_index('DATE').sort_index()
df_BT_Call['Open'] = (df_BT_Call['C_BID'] + df_BT_Call['C_ASK']) / 2
df_BT_Call['High'] = df_BT_Call['Open']
df_BT_Call['Low'] = df_BT_Call['Open']
df_BT_Call['Close'] = df_BT_Call['Open']
df_BT_Call['Volume'] = 0

df_BT_Put = df_Merged_Strike.copy()
df_BT_Put['DATE'] = pd.to_datetime(df_BT_Put['QUOTE_DATE'])
df_BT_Put = df_BT_Put.set_index('DATE').sort_index()
df_BT_Put['Open'] = (df_BT_Put['P_BID'] + df_BT_Put['P_ASK']) / 2
df_BT_Put['High'] = df_BT_Put['Open']
df_BT_Put['Low'] = df_BT_Put['Open']
df_BT_Put['Close'] = df_BT_Put['Open']
df_BT_Put['Volume'] = 0

# Simplified Trading Strategy
class OptionsArbitrage(Strategy):
    Entry_Threshold = 0.2
    Profit_Threshold = 0.05 
    Stop_Loss = 0.05        
    Equity_Percent = 0.01

    def init(self):
        self.is_call = 'C_BID' in self.data.df.columns
        self.diff = self.data.CALL_DIFF if self.is_call else self.data.PUT_DIFF
        self.trade_history = []

    def next(self):
        current_diff = self.diff[-1]
        current_price = self.data.Close[-1]
        current_date = self.data.index[-1]

        # Check and close existing trade
        if self.trades:  # If there’s a trade open
            trade = self.trades[0]  # Only one trade allowed, so take the first
            profit_pct = (current_price - trade.entry_price) / trade.entry_price * (-1 if 'short' in trade.tag else 1)
            exit_reason = None
            
            if 'short' in trade.tag:
                if profit_pct >= self.Profit_Threshold:
                    exit_reason = "TP"
                    print(f"  Hit TP, Profit={profit_pct:.4f} on {current_date.strftime('%Y-%m-%d')}")
                elif profit_pct <= -self.Stop_Loss:                
                    exit_reason = "SL"
                    print(f"  Hit SL, Loss={profit_pct:.4f} on {current_date.strftime('%Y-%m-%d')}")
            else:
                if profit_pct >= self.Profit_Threshold:
                    exit_reason = "TP"
                    print(f"  Hit TP, Profit={profit_pct:.4f} on {current_date.strftime('%Y-%m-%d')}")
                elif profit_pct <= -self.Stop_Loss:
                    exit_reason = "SL"
                    print(f"  Hit SL, Loss={profit_pct:.4f} on {current_date.strftime('%Y-%m-%d')}")
            
            if exit_reason:
                self.trade_history.append({
                    'Type': 'Call' if self.is_call else 'Put',
                    'Direction': 'Short' if 'short' in trade.tag else 'Long',
                    'Entry_Price': trade.entry_price,
                    'Exit_Price': current_price,
                    'Size': trade.size,
                    'Profit_Pct': profit_pct,
                    'Entry_Date': trade.entry_time,
                    'Exit_Date': current_date,
                    'Exit_Reason': exit_reason
                })
                trade.close()

        # Open new trade only if no active trades
        if len(self.trades) == 0:
            equity = self.equity
            trade_value = equity * self.Equity_Percent
            size = max(1, int(trade_value / current_price))
            
            if current_diff > self.Entry_Threshold:
                self.sell(size=size, tag='call_short' if self.is_call else 'put_short')
                print(f"Opened {'Call' if self.is_call else 'Put'} Short Trade: {size} @ {current_price:.2f} on {current_date.strftime('%Y-%m-%d')}")
            elif current_diff < -self.Entry_Threshold:
                self.buy(size=size, tag='call_long' if self.is_call else 'put_long')
                print(f"Opened {'Call' if self.is_call else 'Put'} Long Trade: {size} @ {current_price:.2f} on {current_date.strftime('%Y-%m-%d')}")

    def finalize(self):
        print(f"{'Call' if self.is_call else 'Put'} Trade History Length: {len(self.trade_history)}")
        

# Run backtests
bt_call = Backtest(df_BT_Call, OptionsArbitrage, cash=100000, commission=.002, 
                  exclusive_orders=True, trade_on_close=True)
bt_put = Backtest(df_BT_Put, OptionsArbitrage, cash=100000, commission=.002, 
                 exclusive_orders=True, trade_on_close=True)

stats_call = bt_call.run()
print("\nCall Options Backtest Results:")
print(stats_call)

stats_put = bt_put.run()
print("\nPut Options Backtest Results:")
print(stats_put)

bt_call.plot(filename='call_backtest_results.html')
bt_put.plot(filename='put_backtest_results.html')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7940\735333136.py:31: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_Option_Filtered = df_Options.groupby('QUOTE_DATE').apply(Get_Nth_Closest_Expiry).reset_index(drop=True)
# Opened Call Short Trade: 56 @ 17.64 on 2023-01-04
#   Hit SL, Loss=-0.1012 on 2023-01-09
# Opened Call Short Trade: 57 @ 17.34 on 2023-01-10
#   Hit TP, Profit=0.0836 on 2023-01-17
# Opened Call Short Trade: 63 @ 15.63 on 2023-01-18
#   Hit SL, Loss=-0.0636 on 2023-01-20
# Opened Call Short Trade: 55 @ 18.09 on 2023-01-23
#   Hit TP, Profit=0.0633 on 2023-01-24
# Opened Call Short Trade: 59 @ 16.73 on 2023-01-25
#   Hit SL, Loss=-0.0921 on 2023-01-30
# Opened Call Short Trade: 59 @ 16.78 on 2023-01-31
#   Hit SL, Loss=-0.0781 on 2023-02-06
# Opened Call Short Trade: 77 @ 12.89 on 2023-12-26
#
# Call Options Backtest Results:
# Start                     2023-01-03 00:00:00
# End                       2023-12-29 00:00:00
# Duration                    360 days 00:00:00
# Exposure Time [%]                        98.0
# Equity Final [$]                  99879.68221
# Equity Peak [$]                  100076.66425
# Commissions [$]                     229.57196
# Return [%]                           -0.12032
# Buy & Hold Return [%]               -34.43176
# Return (Ann.) [%]                    -0.12128
# Volatility (Ann.) [%]                 0.61786
# CAGR [%]                             -0.08424
# Sharpe Ratio                         -0.19629
# Sortino Ratio                        -0.26786
# Calmar Ratio                         -0.29076
# Alpha [%]                            -0.37014
# Beta                                 -0.00726
# Max. Drawdown [%]                    -0.41711
# Avg. Drawdown [%]                    -0.15473
# Max. Drawdown Duration      327 days 00:00:00
# Avg. Drawdown Duration       72 days 00:00:00
# # Trades                                   58
# Win Rate [%]                         53.44828
# Best Trade [%]                        9.45292
# Worst Trade [%]                     -11.38723
# Avg. Trade [%]                        -0.1095
# Max. Trade Duration          17 days 00:00:00
# Avg. Trade Duration           5 days 00:00:00
# Profit Factor                         1.04551
# Expectancy [%]                        0.15831
# SQN                                   0.16461
# Kelly Criterion                       0.02334
# _strategy                    OptionsArbitrage
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# Opened Call Short Trade: 216 @ 4.62 on 2023-01-04
#   Hit SL, Loss=-0.1538 on 2023-01-05
# Opened Call Short Trade: 209 @ 4.78 on 2023-01-06
#   Hit SL, Loss=-0.1958 on 2023-01-09
# Opened Call Short Trade: 228 @ 4.36 on 2023-01-10
#   Hit TP, Profit=0.2144 on 2023-01-12
# Opened Call Short Trade: 258 @ 3.87 on 2023-01-13
#   Hit TP, Profit=0.2393 on 2023-01-17
# Opened Call Short Trade: 321 @ 3.11 on 2023-01-18
#   Hit SL, Loss=-0.2154 on 2023-01-20
# Opened Call Short Trade: 260 @ 3.84 on 2023-01-23
#   Hit TP, Profit=0.1745 on 2023-01-24
# Opened Call Short Trade: 322 @ 3.10 on 2023-01-25
#   Hit TP, Profit=0.0628 on 2023-01-26
# Opened Call Short Trade: 316 @ 3.16 on 2023-01-27
#   Hit SL, Loss=-0.2785 on 2023-01-30
# Opened Call Short Trade: 309 @ 3.23 on 2023-01-31
#   Hit TP, Profit=0.1548 on 2023-02-01
# Opened Call Short Trade: 389 @ 2.56 on 2023-02-02
#   Hit SL, Loss=-0.2515 on 2023-02-03
# Opened Call Short Trade: 249 @ 3.99 on 2023-02-06
#   Hit TP, Profit=0.1040 on 2023-02-07
# Opened Call Short Trade: 259 @ 3.85 on 2023-02-08
#   Hit SL, Loss=-0.4753 on 2023-02-09
# Opened Call Short Trade: 152 @ 6.53 on 2023-02-10
#   Hit TP, Profit=0.2161 on 2023-02-14
# Opened Call Short Trade: 205 @ 4.84 on 2023-02-15
#   Hit TP, Profit=0.0950 on 2023-02-16
# Opened Call Short Trade: 189 @ 5.26 on 2023-02-17
#   Hit TP, Profit=0.1540 on 2023-02-21
# Opened Call Short Trade: 245 @ 4.07 on 2023-02-22
#   Hit TP, Profit=0.1437 on 2023-02-23
# Opened Call Short Trade: 211 @ 4.71 on 2023-02-24
#   Hit SL, Loss=-0.0817 on 2023-02-27
# Opened Call Short Trade: 269 @ 3.71 on 2023-02-28
#   Hit SL, Loss=-0.0904 on 2023-03-01
# Opened Call Short Trade: 260 @ 3.83 on 2023-03-02
#   Hit TP, Profit=0.0796 on 2023-03-06
# Opened Call Short Trade: 263 @ 3.79 on 2023-03-07
#   Hit TP, Profit=0.0568 on 2023-03-08
# Opened Call Short Trade: 223 @ 4.47 on 2023-03-09
#   Hit SL, Loss=-0.1844 on 2023-03-10
# Opened Call Short Trade: 170 @ 5.83 on 2023-03-13
#   Hit TP, Profit=0.2271 on 2023-03-14
# Opened Call Short Trade: 191 @ 5.21 on 2023-03-15
#   Hit TP, Profit=0.2274 on 2023-03-16
# Opened Call Short Trade: 165 @ 6.06 on 2023-03-17
#   Hit TP, Profit=0.1583 on 2023-03-20
# Opened Call Short Trade: 239 @ 4.19 on 2023-03-21
#   Hit SL, Loss=-0.2041 on 2023-03-23
# Opened Call Short Trade: 168 @ 5.93 on 2023-03-24
#   Hit TP, Profit=0.1535 on 2023-03-27
# Opened Call Short Trade: 221 @ 4.53 on 2023-03-28
#   Hit TP, Profit=0.0640 on 2023-03-29
# Opened Call Short Trade: 254 @ 3.94 on 2023-03-30
#   Hit SL, Loss=-0.1652 on 2023-03-31
# Opened Call Short Trade: 241 @ 4.14 on 2023-04-03
#   Hit TP, Profit=0.0954 on 2023-04-06
# Opened Call Short Trade: 229 @ 4.37 on 2023-04-10
#   Hit TP, Profit=0.2094 on 2023-04-11
# Opened Call Short Trade: 313 @ 3.20 on 2023-04-12
#   Hit TP, Profit=0.1578 on 2023-04-13
# Opened Call Short Trade: 335 @ 3.00 on 2023-04-14
#   Hit TP, Profit=0.0617 on 2023-04-17
# Opened Call Short Trade: 381 @ 2.64 on 2023-04-18
#   Hit SL, Loss=-0.0587 on 2023-04-20
# Opened Call Short Trade: 327 @ 3.08 on 2023-04-21
#   Hit SL, Loss=-0.1805 on 2023-04-24
# Opened Call Short Trade: 279 @ 3.59 on 2023-04-25
#   Hit TP, Profit=0.0570 on 2023-04-26
# Opened Call Short Trade: 393 @ 2.55 on 2023-04-27
#   Hit SL, Loss=-0.1213 on 2023-04-28
# Opened Call Short Trade: 415 @ 2.42 on 2023-05-01
#   Hit SL, Loss=-0.2588 on 2023-05-02
# Opened Call Short Trade: 312 @ 3.21 on 2023-05-03
#   Hit SL, Loss=-0.1076 on 2023-05-04
# Opened Call Short Trade: 296 @ 3.37 on 2023-05-05
#   Hit SL, Loss=-0.0979 on 2023-05-08
# Opened Call Short Trade: 334 @ 2.98 on 2023-05-09
#   Hit TP, Profit=0.1544 on 2023-05-10
# Opened Call Short Trade: 428 @ 2.33 on 2023-05-11
#   Hit SL, Loss=-0.3191 on 2023-05-12
# Opened Call Short Trade: 248 @ 4.01 on 2023-05-15
#   Hit TP, Profit=0.1108 on 2023-05-17
# Opened Call Short Trade: 321 @ 3.10 on 2023-05-18
#   Hit SL, Loss=-0.2097 on 2023-05-19
# Opened Call Short Trade: 220 @ 4.51 on 2023-05-22
#   Hit TP, Profit=0.0809 on 2023-05-23
# Opened Call Short Trade: 215 @ 4.62 on 2023-05-24
#   Hit TP, Profit=0.0930 on 2023-05-25
# Opened Call Short Trade: 231 @ 4.30 on 2023-05-26
#   Hit TP, Profit=0.2907 on 2023-05-30
# Opened Call Short Trade: 341 @ 2.92 on 2023-05-31
#   Hit TP, Profit=0.2171 on 2023-06-01
# Opened Call Short Trade: 401 @ 2.50 on 2023-06-02
#   Hit SL, Loss=-0.1263 on 2023-06-05
# Opened Call Short Trade: 401 @ 2.49 on 2023-06-06
#   Hit TP, Profit=0.0703 on 2023-06-07
# Opened Call Short Trade: 473 @ 2.12 on 2023-06-08
#   Hit SL, Loss=-0.2270 on 2023-06-09
# Opened Call Short Trade: 365 @ 2.73 on 2023-06-12
#   Hit TP, Profit=0.0897 on 2023-06-13
# Opened Call Short Trade: 419 @ 2.38 on 2023-06-14
#   Hit SL, Loss=-0.1824 on 2023-06-16
# Opened Call Short Trade: 409 @ 2.44 on 2023-06-20
#   Hit TP, Profit=0.1725 on 2023-06-22
# Opened Call Short Trade: 353 @ 2.83 on 2023-06-23
#   Hit TP, Profit=0.1416 on 2023-06-27
# Opened Call Short Trade: 424 @ 2.36 on 2023-06-28
#   Hit SL, Loss=-0.0614 on 2023-07-03
# Opened Call Short Trade: 513 @ 1.95 on 2023-07-05
#   Hit SL, Loss=-0.1897 on 2023-07-06
# Opened Call Short Trade: 397 @ 2.51 on 2023-07-07
#   Hit TP, Profit=0.0896 on 2023-07-11
# Opened Call Short Trade: 555 @ 1.80 on 2023-07-12
#   Hit TP, Profit=0.0972 on 2023-07-13
# Opened Call Short Trade: 466 @ 2.15 on 2023-07-14
#   Hit TP, Profit=0.1352 on 2023-07-17
# Opened Call Short Trade: 551 @ 1.81 on 2023-07-18
#   Hit SL, Loss=-0.2011 on 2023-07-21
# Opened Call Short Trade: 493 @ 2.02 on 2023-07-24
#   Hit TP, Profit=0.1852 on 2023-07-26
# Opened Call Short Trade: 517 @ 1.94 on 2023-07-27
#   Hit SL, Loss=-0.0672 on 2023-07-28
# Opened Call Short Trade: 509 @ 1.96 on 2023-07-31
#   Hit SL, Loss=-0.2723 on 2023-08-02
# Opened Call Short Trade: 425 @ 2.34 on 2023-08-03
#   Hit SL, Loss=-0.5032 on 2023-08-04
# Opened Call Short Trade: 373 @ 2.66 on 2023-08-07
#   Hit SL, Loss=-0.0734 on 2023-08-11
# Opened Call Short Trade: 391 @ 2.54 on 2023-08-14
#   Hit SL, Loss=-0.0986 on 2023-08-15
# Opened Call Short Trade: 331 @ 2.99 on 2023-08-16
#   Hit SL, Loss=-0.2575 on 2023-08-18
# Opened Call Short Trade: 230 @ 4.28 on 2023-08-21
#   Hit TP, Profit=0.1133 on 2023-08-23
# Opened Call Short Trade: 241 @ 4.09 on 2023-08-24
#   Hit TP, Profit=0.0892 on 2023-08-28
# Opened Call Short Trade: 312 @ 3.17 on 2023-08-29
#   Hit TP, Profit=0.0978 on 2023-08-30
# Opened Call Short Trade: 379 @ 2.62 on 2023-08-31
#   Hit SL, Loss=-0.1530 on 2023-09-01
# Opened Call Short Trade: 413 @ 2.40 on 2023-09-05
#   Hit SL, Loss=-0.1232 on 2023-09-08
# Opened Call Short Trade: 407 @ 2.42 on 2023-09-11
#   Hit SL, Loss=-0.0577 on 2023-09-12
# Opened Call Short Trade: 479 @ 2.06 on 2023-09-13
#   Hit TP, Profit=0.1675 on 2023-09-14
# Opened Call Short Trade: 371 @ 2.67 on 2023-09-15
#   Hit TP, Profit=0.0563 on 2023-09-18
# Opened Call Short Trade: 397 @ 2.49 on 2023-09-19
#   Hit SL, Loss=-0.0703 on 2023-09-20
# Opened Call Short Trade: 323 @ 3.06 on 2023-09-21
#   Hit SL, Loss=-0.2549 on 2023-09-22
# Opened Call Short Trade: 276 @ 3.58 on 2023-09-25
#   Hit SL, Loss=-0.1524 on 2023-09-26
# Opened Call Short Trade: 257 @ 3.83 on 2023-09-27
#   Hit TP, Profit=0.1242 on 2023-09-28
# Opened Call Short Trade: 243 @ 4.04 on 2023-09-29
#   Hit TP, Profit=0.0667 on 2023-10-02
# Opened Call Short Trade: 234 @ 4.21 on 2023-10-03
#   Hit TP, Profit=0.1805 on 2023-10-04
# Opened Call Short Trade: 285 @ 3.46 on 2023-10-05
#   Hit SL, Loss=-0.1501 on 2023-10-06
# Opened Call Short Trade: 259 @ 3.81 on 2023-10-09
#   Hit TP, Profit=0.1220 on 2023-10-10
# Opened Call Short Trade: 327 @ 3.02 on 2023-10-11
#   Hit SL, Loss=-0.4785 on 2023-10-13
# Opened Call Short Trade: 271 @ 3.62 on 2023-10-16
#   Hit SL, Loss=-0.1283 on 2023-10-18
# Opened Call Short Trade: 232 @ 4.23 on 2023-10-19
#   Hit SL, Loss=-0.2553 on 2023-10-20
# Opened Call Short Trade: 209 @ 4.69 on 2023-10-23
#   Hit TP, Profit=0.1249 on 2023-10-24
# Opened Call Short Trade: 222 @ 4.41 on 2023-10-25
#   Hit SL, Loss=-0.2007 on 2023-10-27
# Opened Call Short Trade: 231 @ 4.22 on 2023-10-30
#   Hit TP, Profit=0.1361 on 2023-10-31
# Opened Call Short Trade: 325 @ 3.01 on 2023-11-01
#   Hit TP, Profit=0.1177 on 2023-11-02
# Opened Call Short Trade: 333 @ 2.94 on 2023-11-03
#   Hit TP, Profit=0.1139 on 2023-11-06
# Opened Call Short Trade: 405 @ 2.42 on 2023-11-07
#   Hit TP, Profit=0.0536 on 2023-11-08
# Opened Call Short Trade: 312 @ 3.15 on 2023-11-09
#   Hit SL, Loss=-0.1873 on 2023-11-10
# Opened Call Short Trade: 259 @ 3.78 on 2023-11-13
#   Hit TP, Profit=0.1376 on 2023-11-14
# Opened Call Short Trade: 322 @ 3.04 on 2023-11-15
#   Hit TP, Profit=0.0805 on 2023-11-16
# Opened Call Short Trade: 293 @ 3.35 on 2023-11-17
#   Hit TP, Profit=0.1299 on 2023-11-20
# Opened Call Short Trade: 301 @ 3.26 on 2023-11-21
#   Hit TP, Profit=0.1764 on 2023-11-22
# Opened Call Short Trade: 419 @ 2.35 on 2023-11-24
#   Hit TP, Profit=0.0787 on 2023-11-28
# Opened Call Short Trade: 414 @ 2.38 on 2023-11-29
#   Hit TP, Profit=0.1176 on 2023-11-30
# Opened Call Short Trade: 388 @ 2.54 on 2023-12-01
#   Hit TP, Profit=0.0629 on 2023-12-05
# Opened Call Short Trade: 419 @ 2.35 on 2023-12-06
#   Hit TP, Profit=0.0764 on 2023-12-07
# Opened Call Short Trade: 417 @ 2.37 on 2023-12-08
#   Hit SL, Loss=-0.2046 on 2023-12-11
# Opened Call Short Trade: 393 @ 2.51 on 2023-12-12
#   Hit TP, Profit=0.0797 on 2023-12-13
# Opened Call Short Trade: 414 @ 2.38 on 2023-12-14
#   Hit SL, Loss=-0.1300 on 2023-12-15
# Opened Call Short Trade: 291 @ 3.38 on 2023-12-18
#   Hit SL, Loss=-0.1361 on 2023-12-20
# Opened Call Short Trade: 283 @ 3.47 on 2023-12-21
#   Hit SL, Loss=-0.1023 on 2023-12-22
# Opened Call Short Trade: 340 @ 2.89 on 2023-12-26
#   Hit TP, Profit=0.0830 on 2023-12-27
# Opened Call Short Trade: 389 @ 2.53 on 2023-12-28
#   Hit SL, Loss=-0.1897 on 2023-12-29
#
# Put Options Backtest Results:
# Start                     2023-01-03 00:00:00
# End                       2023-12-29 00:00:00
# Duration                    360 days 00:00:00
# Exposure Time [%]                        98.8
# Equity Final [$]                  98299.23672
# Equity Peak [$]                  100661.42464
# Commissions [$]                     427.06494
# Return [%]                           -1.70076
# Buy & Hold Return [%]               -46.67848
# Return (Ann.) [%]                    -1.71425
# Volatility (Ann.) [%]                 1.79806
# CAGR [%]                             -1.19359
# Sharpe Ratio                         -0.95339
# Sortino Ratio                        -1.15557
# Calmar Ratio                         -0.62323
# Alpha [%]                             -1.9552
# Beta                                 -0.00545
# Max. Drawdown [%]                    -2.75059
# Avg. Drawdown [%]                    -0.41579
# Max. Drawdown Duration      254 days 00:00:00
# Avg. Drawdown Duration       36 days 00:00:00
# # Trades                                  107
# Win Rate [%]                         56.07477
# Best Trade [%]                       29.06977
# Worst Trade [%]                     -50.31983
# Avg. Trade [%]                       -2.71596
# Max. Trade Duration           5 days 00:00:00
# Avg. Trade Duration           2 days 00:00:00
# Profit Factor                          0.8766
# Expectancy [%]                       -1.00272
# SQN                                  -0.60367
# Kelly Criterion                      -0.08047
# _strategy                    OptionsArbitrage
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# GridPlot(id='p10131', ...)
